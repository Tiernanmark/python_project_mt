# %%
class Episode:
    def __init__(self, season, episode, title, air_date):
        self.season = season
        self.episode = episode
        self.title = title
        self.air_date = air_date

    def __str__(self):
        return f"'{self.title}' is episode {self.episode} of season {self.season} originally aired {self.air_date}"

    summary = __str__

    def full_list_of_episodes(self):
        return [summary() for s in self]

# %%
episode1_1 = Episode(1, 1, "The Good Son", "16 September 1993")
episode1_2 = Episode(1, 2, "Space Quest", "23 September 1993")
episode1_3 = Episode(1, 3, "Dinner At Eight", "30 September 1993")
episode1_4 = Episode(1, 4, "I Hate Frasier Crane",	"7 October 1993")
episode1_5 = Episode(1, 5, "Here's Looking At You", "214 October 1993")
episode1_6 = Episode(1, 6, "The Crucible",	"21 October 1993")
episode1_7 = Episode(1, 7, "Call Me Irresponsible", "28 October 1993")
episode1_8 = Episode(1, 8, "Beloved Infidel", "4 November 1993")
episode1_9 = Episode(1, 9, "Selling Out", "11 November 1993")
episode1_10 = Episode(1, 10, "Oops", "18 November 1993")
episode1_11 = Episode(1, 11, "Death Becomes Him", "2 December 1993")
episode1_12 = Episode(1, 12, "Miracle On Third Or Fourth Street", "16 December 1993")
episode1_13 = Episode(1, 13, "Guess Who's Coming To Breakfast", "6 January 1994")
episode1_14 = Episode(1, 14, "Can't Buy Me Love", "20 January 1994")
episode1_15 = Episode(1, 15, "You Can't Tell A Crook By His Cover", "27 January 1994")
episode1_16 = Episode(1, 16, "The Show Where Lilith Comes Back", "3 February 1994")
episode1_17 = Episode(1, 17, "A Mid-Winter Night's Dream", "10 February 1994")
episode1_18 = Episode(1, 18, "And The Whimper Is...", "17 February 1994")
episode1_19 = Episode(1, 19, "Give Him The Chair!", "17 March 1994")
episode1_20 = Episode(1, 20, "Fortysomething", "31 March 1994")
episode1_21 = Episode(1, 21, "Travels With Martin", "14 April 1994")
episode1_22 = Episode(1, 22, "Author, Author", "5 May 1994")
episode1_23 = Episode(1, 23, "Frasier Crane's Day Off", "12 May 1994")
episode1_24 = Episode(1, 24, "My Coffee With Niles", "19 May 1994")
episode2_1 = Episode(2, 1, "Slow Tango In South Seattle", "20 SEPTEMBER 1994")
episode2_2 = Episode(2, 2, "The Unkindest Cut Of All", "27 SEPTEMBER 1994")
episode2_3 = Episode(2, 3, "The Matchmaker", "4 OCTOBER 1994")
episode2_4 = Episode(2, 4, "Flour Child", "11 OCTOBER 1994")
episode2_5 = Episode(2, 5, "Duke's, We Hardly Knew Ye", "18 OCTOBER 1994")
episode2_6 = Episode(2, 6, "The Botched Language Of Cranes", "1 NOVEMBER 1994")
episode2_7 = Episode(2, 7, "The Candidate", "8 NOVEMBER 1994")
episode2_8 = Episode(2, 8, "Adventures In Paradise: Part 1", "15 NOVEMBER 1994")
episode2_9 = Episode(2, 9, "Adventures In Paradise: Part 2", "22 NOVEMBER 1994")
episode2_10 = Episode(2, 10, "Burying A Grudge", "29 NOVEMBER 1994")
episode2_11 = Episode(2, 11, "Seat Of Power", "13 DECEMBER 1994")
episode2_12 = Episode(2, 12, "Roz In The Doghouse", "3 JANUARY 1995")
episode2_13 = Episode(2, 13, "Retirement Is Murder", "10 JANUARY 1995")
episode2_14 = Episode(2, 14, "Fool Me Once, Shame On You, Fool Me Twice...", "7 FEBRUARY 1995")
episode2_15 = Episode(2, 15, "You Scratch My Book...", "14 FEBRUARY 1995")
episode2_16 = Episode(2, 16, "The Show Where Sam Shows Up", "21 FEBRUARY 1995")
episode2_17 = Episode(2, 17, "Daphne's Room", "28 FEBRUARY 1995")
episode2_18 = Episode(2, 18, "The Club", "21 MARCH 1995")
episode2_19 = Episode(2, 19, "Someone To Watch Over Me", "28 MARCH 1995")
episode2_20 = Episode(2, 20, "Breaking The Ice", "18 APRIL 1995")
episode2_21 = Episode(2, 21, "An Affair To Forget", "2 MAY 1995")
episode2_22 = Episode(2, 22, "Agents In America: Part 3", "9 MAY 1995")
episode2_23 = Episode(2, 23, "The Innkeepers", "16 MAY 1995")
episode2_24 = Episode(2, 24, "Dark Victory", "23 MAY 1995") 
episode3_1 = Episode(3, 1, "She's The Boss", "19 September 1995")
episode3_2 = Episode(3, 2, "Shrink Rap", "26 September 1995")
episode3_3 = Episode(3, 3, "Martin Does It His Way", "10 October 1995")
episode3_4 = Episode(3, 4, "Leapin' Lizards", "31 October 1995")
episode3_5 = Episode(3, 5, "Kisses Sweeter Than Wine", "7 November 1995")
episode3_6 = Episode(3, 6, "Sleeping With The Enemy", "14 November 1995")
episode3_7 = Episode(3, 7, "The Adventures of Bad Boy and Dirty Girl", "21 November 1995")
episode3_8 = Episode(3, 8, "The Last Time I Saw Maris", "28 November 1995")
episode3_9 = Episode(3, 9, "Frasier Grinch", "19 December 1995")
episode3_10 = Episode(3, 10, "It's Hard To Say Goodbye If You Won't Leave", "9 January 1996")
episode3_11 = Episode(3, 11, "The Friend", "16 January 1996")
episode3_12 = Episode(3, 12, "Come Lie With Me", "30 January 1996")
episode3_13 = Episode(3, 13, "Moon Dance", "6 February 1996")
episode3_14 = Episode(3, 14, "The Show Where Diane Comes Back", "13 February 1996")
episode3_15 = Episode(3, 15, "A Word To The Wiseguy", "20 February 1996")
episode3_16 = Episode(3, 16, "Look Before You Leap", "27 February 1996")
episode3_17 = Episode(3, 17, "High Crane Drifter", "12 March 1996")
episode3_18 = Episode(3, 18, "Chess Pains", "26 March 1996")
episode3_19 = Episode(3, 19, "Crane vs. Crane", "9 April 1996")
episode3_20 = Episode(3, 20, "Police Story", "23 April 1996")
episode3_21 = Episode(3, 21, "Where There's Smoke, There's Fired", "30 April 1996")
episode3_22 = Episode(3, 22, "Frasier Loves Roz", "7 May 1996")
episode3_23 = Episode(3, 23, "The Focus Group", "14 May 1996")
episode3_24 = Episode(3, 24, "You Can Go Home Again", "21 May 1996")

# %%
print(episode1_13)
# Out:
# 'Guess Who's Coming To Breakfast' is episode 13 of season 1 originally aired 6 January 1994
